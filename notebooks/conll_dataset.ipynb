# %%
import pandas as pd

# %%
# !ls ../conll_experiments/data
# Out:
# ner  ner.tgz  test.txt	train.txt  val.txt

# %%
TRAIN_FILE = "../conll_experiments/data/train.txt"

# %%
train_df = pd.read_csv(TRAIN_FILE, sep=" ",).fillna("<UNK>")

# %%
train_df = pd.read_csv(TRAIN_FILE, sep=" ", header=None)

# %%
train_df
# Out:
#         -DOCSTART-  -X- -X-.1       O
# 0               EU  NNP  B-NP   B-ORG
# 1          rejects  VBZ  B-VP       O
# 2           German   JJ  B-NP  B-MISC
# 3             call   NN  I-NP       O
# 4               to   TO  B-VP       O
# 5          boycott   VB  I-VP       O
# 6          British   JJ  B-NP  B-MISC
# 7             lamb   NN  I-NP       O
# 8                .    .     O       O
# 9            Peter  NNP  B-NP   B-PER
# 10       Blackburn  NNP  I-NP   I-PER
# 11        BRUSSELS  NNP  B-NP   B-LOC
# 12      1996-08-22   CD  I-NP       O
# 13             The   DT  B-NP       O
# 14        European  NNP  I-NP   B-ORG
# 15      Commission  NNP  I-NP   I-ORG
# 16            said  VBD  B-VP       O
# 17              on   IN  B-PP       O
# 18        Thursday  NNP  B-NP       O
# 19              it  PRP  B-NP       O
# 20       disagreed  VBD  B-VP       O
# 21            with   IN  B-PP       O
# 22          German   JJ  B-NP  B-MISC
# 23          advice   NN  I-NP       O
# ...
